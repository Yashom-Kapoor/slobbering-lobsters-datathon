# %%
import pandas as pd 

df = pd.read_csv("../../backend/data/dropped_rows.csv")
df["sdg_focus"] = df["sdg_focus"].astype(str).str.strip()
df["region"] = df["region"].astype(str).str.strip()

df.head()
# Out:
# /var/folders/sp/zrg_wt6n4hs4l4nz5y1b6zs00000gn/T/ipykernel_56760/2744818498.py:3: DtypeWarning: Columns (0: grant_recipient_project_title) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../backend/data/dropped_rows.csv")
#    year   organization_name          region country  usd_disbursements_defl  \
# 0  2022  True Colours Trust  Eastern Africa  Malawi                0.041862
# 1  2020  True Colours Trust  Eastern Africa  Malawi                0.054969
# 2  2021  True Colours Trust  Eastern Africa  Malawi                0.366887
# 3  2021  True Colours Trust  Eastern Africa  Malawi                0.366887
# 4  2020  True Colours Trust  Eastern Africa  Malawi                0.016170
#
#                        grant_recipient_project_title   Donor_country  \
# 0  Towards the costs of updating lockable cupboar...  United Kingdom
# 1  Towards the purchase of PPE during the COVID19...  United Kingdom
# 2  Towards Phase 5 of integrating palliative care...  United Kingdom
# 3  Towards Phase 5 of integrating palliative care...  United Kingdom
# 4  Towards the production of films on Palliative ...  United Kingdom
#
#   sdg_focus                                       mission_desc
# 0       3.4  Achieve By 2030, reduce by one third premature...
# 1       3.3  Achieve By 2030, end the epidemics of AIDS, tu...
# 2       3.8  Achieve Achieve universal health coverage, inc...
# 3       3.8  Achieve Achieve universal health coverage, inc...
# 4       3.4  Achieve By 2030, reduce by one third premature...

# %%
sdg = "3.4"
region = "Eastern Africa"

data = df[(df["sdg_focus"] == sdg) & (df["region"] == region)]
total_min = data[["year", "usd_disbursements_defl"]].groupby("year").sum().reset_index()["usd_disbursements_defl"].iloc[0]
total_max = data[["year", "usd_disbursements_defl"]].groupby("year").sum().reset_index()["usd_disbursements_defl"].iloc[-1]
growth = total_max - total_min
# Out:
# np.float64(85.13048310584422)

# %%
total_funding = data['usd_disbursements_defl'].sum()
total_funding
# Out:
# np.float64(380.8501553137178)

# %%
num_orgs = len(data["organization_name"].unique())
num_proj = len(data["grant_recipient_project_title"].unique())
num_countries = len(data["country"].unique())
# Out:
# 24

# %%
url = "https://raw.githubusercontent.com/datasets/country-codes/master/data/country-codes.csv"
countries_df = pd.read_csv(url)
countries_df = countries_df[["CLDR display name", "ISO3166-1-Alpha-3"]]
countries_df.columns = ["Name", "ISO"]
countries_df.head()
# Out:
#               Name  ISO
# 0      Afghanistan  AFG
# 1  Kepulauan Aland  ALA
# 2          Albania  ALB
# 3          Algeria  DZA
# 4    Samoa Amerika  ASM

# %%
countries_df[""]
# Out:
#                   Name  ISO
# 0          Afghanistan  AFG
# 1      Kepulauan Aland  ALA
# 2              Albania  ALB
# 3              Algeria  DZA
# 4        Samoa Amerika  ASM
# ..                 ...  ...
# 244  Wallis dan Futuna  WLF
# 245       Sahara Barat  ESH
# 246              Yaman  YEM
# 247             Zambia  ZMB
# 248           Zimbabwe  ZWE
#
# [249 rows x 2 columns]
