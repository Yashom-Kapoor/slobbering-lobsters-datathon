# %%
import pandas as pd 

df = pd.read_csv("../../data/clean_year_region.csv")
df.head()
# Out:
# /var/folders/sp/zrg_wt6n4hs4l4nz5y1b6zs00000gn/T/ipykernel_53996/3939303601.py:3: DtypeWarning: Columns (0: grant_recipient_project_title, 1: expected_duration, 2: financial_instrument, 3: modality_of_giving, 4: gender_dimension, 5: additional_info, 6: subsector, 7: Sector, 8: channel_name, 9: channel_reported_name) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../data/clean_year_region.csv")
#    year organization_name                region      country  \
# 0  2021        Lund Trust  South & Central Asia  Afghanistan
# 1  2021        Lund Trust        Eastern Africa        Kenya
# 2  2022        Lund Trust                Europe      Ukraine
# 3  2022        Lund Trust                Europe      Ukraine
# 4  2022        Lund Trust                Europe      Ukraine
#
#    usd_disbursements_defl                      grant_recipient_project_title  \
# 0                0.007338                                    For Afghanistan
# ...

# %%
df.groupby("sector_description").count()
df[["sdg_focus"]]
df.groupby("sdg_focus").count().sort_values("year", ascending=False)
# Out:
#                            year  organization_name  region  country  \
# sdg_focus
# 3.8                        8753               8753    8753     8753
# 3;17                       5625               5625    5625     5625
# 3.4                        3256               3256    3256     3256
# 4.3                        2802               2802    2802     2802
# 5;3;17                     2263               2263    2263     2263
# ...                         ...                ...     ...      ...
# 5.2;5.1;16.7;13;10.3;10.2     1                  1       1        1
# 2.2;2.3;5.5;15.3              1                  1       1        1
# 5.2;5.1;17;10.2               1                  1       1        1
# 5.2;5.1;17;16.10;10.2         1                  1       1        1
# 4.2;4.3;4.b                   1                  1       1        1
#
#                            usd_disbursements_defl  \
# sdg_focus
# 3.8                                          8750
# ...
